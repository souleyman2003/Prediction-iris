# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
import warnings

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
#pour pouvoir installer xgboost directement au niveau de jupiter sans le prompt
#!pip install xgboost

import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# Uploading and understanding the dataset

# %%
iris=pd.read_csv("iris.csv")
iris.head()
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           5.0          3.6           1.4          0.2  setosa

# %%
iris
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 0             1           5.1          3.5           1.4          0.2
# 1             2           4.9          3.0           1.4          0.2
# 2             3           4.7          3.2           1.3          0.2
# 3             4           4.6          3.1           1.5          0.2
# 4             5           5.0          3.6           1.4          0.2
# ..          ...           ...          ...           ...          ...
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           5.9          3.0           5.1          1.8
#
#        Species
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# ...

# %%
iris.columns
# Out:
# Index(['FlowerID', 'Sepal.Length', 'Sepal.Width', 'Petal.Length',
#        'Petal.Width', 'Species'],
#       dtype='object')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   FlowerID      150 non-null    int64
#  1   Sepal.Length  150 non-null    float64
#  2   Sepal.Width   150 non-null    float64
#  3   Petal.Length  150 non-null    float64
#  4   Petal.Width   150 non-null    float64
#  5   Species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#statisticals values with numericals data type
iris.describe().T
# Out:
#               count       mean        std  min    25%    50%     75%    max
# FlowerID      150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# Sepal.Length  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# Sepal.Width   150.0   3.057333   0.435866  2.0   2.80   3.00    3.30    4.4
# Petal.Length  150.0   3.758000   1.765298  1.0   1.60   4.35    5.10    6.9
# Petal.Width   150.0   1.199333   0.762238  0.1   0.30   1.30    1.80    2.5

# %%
#statisticals values with categoricals data type
iris.describe(exclude =np.number).T
# Out:
#         count unique     top freq
# Species   150      3  setosa   50

# %% [markdown]
# Donc, on a qu'une seule valeur non numérique

# %%
iris.isnull().sum()
# Out:
# Unnamed: 0      0
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# dtype: int64

# %% [markdown]
# **Observation**:
# On constate que ce dataset, bien structuré, ne contient ni de valeurs nulles, ni de valeurs manquantes.
#
# **Optimisation du modèle**:
# *-Variable non influente*: Unnamed:0
# *-Variable target*: Species

# %% [markdown]
# ***Exploratory data analysis***

# %% [markdown]
# ***-Understanding the variable Sepal.lenght:***
#
#
# C'est une variable quantitative continue. Elle représente la longueur des sépales de la fleur.

# %%
sns.histplot(iris['Sepal.Length'], kde=True)
# Out:
# <Axes: xlabel='Sepal.Length', ylabel='Count'>

# %% [markdown]
# On constate que les longueurs des sépales varient entre 4.5 et 8 cm.
# Mais la quantité de fleurs dont la longueur des sépales varient de 5.5 et 6.5 est plus importante

# %% [markdown]
# ***-Understanding the variable Petal.lenght:***
#
#
# C'est une variable quantitative continue. Elle représente la longueur des pétales de la fleur.

# %%
sns.histplot(iris['Petal.Length'], kde=True)
# Out:
# <Axes: xlabel='Petal.Length', ylabel='Count'>

# %% [markdown]
# On constate que les largeurs des pétales varient entre 1 et 7cm; Mais celles entre 1 et 2cm sont plus importantes.

# %% [markdown]
# ***-Understanding the variable Petal.Width:***
#
#
# C'est une variable quantitative continue. Elle représente la largeur des pétales de la fleur

# %%
sns.histplot(iris['Petal.Width'], kde=True)
# Out:
# <Axes: xlabel='Petal.Width', ylabel='Count'>

# %% [markdown]
# On constate que les largeurs des pétales varient entre 0.1 et 2.5 cm. Mais la quantité de fleurs dont la largeur des pétales varient de 0.1 et 0.4 est plus importante

# %% [markdown]
# ***-Understanding the variable Sepal.Width:***
#
#
# C'est une variable quantitative continue. Elle représente la largeur des sépales de la fleur

# %%
sns.histplot(iris['Sepal.Width'], kde=True)
# Out:
# <Axes: xlabel='Sepal.Width', ylabel='Count'>

# %% [markdown]
# On constate que les largeurs des sépales varient entre 2 et 4.4 cm. Mais la quantité de fleurs dont la largeur des sépales varient de 2.75 et 3.1 est plus importante

# %% [markdown]
# ***Understanding the target variable***

# %%
iris['Species'].value_counts(normalize=True)*100
# Out:
# setosa        33.333333
# versicolor    33.333333
# virginica     33.333333
# Name: Species, dtype: float64

# %% [markdown]
# On observe une meme quantité des 3 especes (Setosa, Versicolor et Virginica).
# Il y'a alors équilibre.

# %%
plt.pie(iris["Species"].value_counts(),labels=iris["Species"].value_counts().index,autopct='%.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x10cb6c6b450>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, 'setosa'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'versicolor'),
#   Text(0.5500001486524352, -0.9526278583383436, 'virginica')],
#  [Text(0.2999999837833699, 0.5196152516333385, '33.33%'),
#   Text(-0.5999999999999974, -5.6176054134900006e-08, '33.33%'),
#   Text(0.30000008108314646, -0.5196151954572783, '33.33%')])

# %%
# Renommer la colonne "Unamed 0" pour mieux comprendre le dataset
iris = iris.rename(columns={'Unnamed: 0': 'FlowerID'})

# %%
iris
# Out:
#      FlowerID  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0           1           5.1          3.5           1.4          0.2     setosa
# 1           2           4.9          3.0           1.4          0.2     setosa
# 2           3           4.7          3.2           1.3          0.2     setosa
# 3           4           4.6          3.1           1.5          0.2     setosa
# 4           5           5.0          3.6           1.4          0.2     setosa
# ..        ...           ...          ...           ...          ...        ...
# 145       146           6.7          3.0           5.2          2.3  virginica
# 146       147           6.3          2.5           5.0          1.9  virginica
# 147       148           6.5          3.0           5.2          2.0  virginica
# 148       149           6.2          3.4           5.4          2.3  virginica
# 149       150           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 6 columns]

# %%
#Distribution des longueurs des sépals en fonction des espèces
iris.groupby('Sepal.Length')['Species'].value_counts(normalize=True)*100
# Out:
# Sepal.Length  Species
# 4.3           setosa        100.000000
# 4.4           setosa        100.000000
# 4.5           setosa        100.000000
# 4.6           setosa        100.000000
# 4.7           setosa        100.000000
# 4.8           setosa        100.000000
# 4.9           setosa         66.666667
#               versicolor     16.666667
#               virginica      16.666667
# 5.0           setosa         80.000000
#               versicolor     20.000000
# 5.1           setosa         88.888889
#               versicolor     11.111111
# 5.2           setosa         75.000000
#               versicolor     25.000000
# 5.3           setosa        100.000000
# 5.4           setosa         83.333333
#               versicolor     16.666667
# 5.5           versicolor     71.428571
#               setosa         28.571429
# 5.6           versicolor     83.333333
#               virginica      16.666667
# 5.7           versicolor     62.500000
# ...

# %%
#Graphique pour visualiser la relation entre la longueure des sépales et la largeures des pétales 
sns.scatterplot(x="Sepal.Length",y="Petal.Width",data=iris,hue="Species",size="Petal.Length")
# Out:
# <Axes: xlabel='Sepal.Length', ylabel='Petal.Width'>

# %% [markdown]
# Ce graphique nous permet également de constater que les fleurs d'espèce Viginica ont tendance à avoir les plus grandes longueures de sépal et les plus grandes largeures de pétal

# %%
sns.scatterplot(x="Petal.Length",y="Sepal.Length",data=iris,hue="Species",size="Petal.Length")
# Out:
# <Axes: xlabel='Petal.Length', ylabel='Sepal.Length'>

# %% [markdown]
# ***On constate*** : Les fleurs d'espèce Viginica ont tendance à avoir les plus grandes longueures de sépales et de pétales.

# %%
#Pour avancer nos analyses, visualisons les relations de toutes les variables en fonction de la variable target Species.
#Pour cela, utilisons un pairplot
sns.pairplot(iris, hue="Species")
plt.show()

# %% [markdown]
# D'après ces graphiques ci-dessus, on constate que:
#
# 1- Il existe une forte corrélation entre les longueurs des pétales et des sépales et les largeurs des pétales et des sépales.
#
#
# 2- Les Viginica ont tendance à avoir les plus grandes longeurs de sépal.
#
# 3- Elles ont tendance à avoir aussi les plus grandes largeurs et plus grandes longueurs de petal.
#
#
# 4-  Les Setosa ont tendance à avoir les plus grandes longeurs de sépal.

# %%
# Barplot
sns.barplot(x="Species",y="Petal.Length",data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='Petal.Length'>

# %%
# Barplot
sns.barplot(x="Species",y="Sepal.Length",data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='Sepal.Length'>

# %%
# Barplot
sns.barplot(x="Species",y="Petal.Width",data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='Petal.Width'>

# %%
# Barplot
sns.barplot(x="Species",y="Sepal.Width",data=iris)
# Out:
# <Axes: xlabel='Species', ylabel='Sepal.Width'>

# %%
# Affichage des barplots pour toutes les variables
plt.figure(figsize=(10, 8))
for i, column in enumerate(iris.columns):
    plt.subplot(2, 2, i + 1)
    sns.barplot(x=iris["Species"], y=iris[column])
    plt.title(column)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 4
#       2 plt.figure(figsize=(10, 8))
#       3 for i, column in enumerate(iris.columns):
# ----> 4     plt.subplot(2, 2, i + 1)
#       5     sns.barplot(x=iris["Species"], y=iris[column])
#       6     plt.title(column)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# ...

# %% [markdown]
# Ces visualisations ci-dessus montrent que:
#
#
# les Virginica ont les plus grandes longueurs et plus grandes largeurs des pétales. Tandisque les Setosa ont les plus grandes largeurs des sépales.

# %% [markdown]
# ***DATA TRANSFORMATION***

# %% [markdown]
# Encodons la variable "Species". C'est la seule variable catégorielle.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
iris['Species'] = le.fit_transform(iris['Species'])
iris.head()
# Out:
#    FlowerID  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0         1           5.1          3.5           1.4          0.2        0
# 1         2           4.9          3.0           1.4          0.2        0
# 2         3           4.7          3.2           1.3          0.2        0
# 3         4           4.6          3.1           1.5          0.2        0
# 4         5           5.0          3.6           1.4          0.2        0

# %%
iris.dtypes
# Out:
# FlowerID          int64
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species           int64
# dtype: object

# %% [markdown]
# ***- Suppression de la variable FlowerID***

# %%
iris=iris.drop('FlowerID',axis=1)

# %%
iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
# identify numerical column in dataframe
objnum=[i for i in iris.columns if iris[i].dtype=='int64' or iris[i].dtype=='float64' or iris[i].dtype=='int32' ]
objnum
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %% [markdown]
# ***MODEL BUILD***

# %% [markdown]
# Divisons les données en ensembles de formation et de test à l’aide de la répartition train-test.
# Ensuite, évaluons plusieurs modèles à l’aide de la validation croisée pour trouver le plus performant.

# %%
X=iris.drop('Species',axis=1)
Y=iris['Species']

# %%
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X, Y,test_size=0.2,random_state=17)
print(Xtrain.shape)
print(Xtest.shape)
print(Ytrain.shape)
print(Ytest.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %%
classifiers = [
    ('Logistic Regression', LogisticRegression()),
    ('Decision Tree', DecisionTreeClassifier()),
    ('Random Forest', RandomForestClassifier()),
    ('KNN', KNeighborsClassifier(n_neighbors=5)),
    ('XGB',xgb.XGBClassifier())
]

# Iterate over each classifier and evaluate performance
for clf_name, clf in classifiers:
    # Perform cross-validation
    scores = cross_val_score(clf, Xtrain,Ytrain, cv=4, scoring='accuracy')
    
    # Calculate average performance metrics
    avg_accuracy = scores.mean()
    avg_precision = cross_val_score(clf, Xtrain, Ytrain, cv=4, scoring='precision_macro').mean()
    avg_recall = cross_val_score(clf, Xtrain, Ytrain, cv=4, scoring='recall_macro').mean()
    
    # Print the performance metrics
    print(f'Classifier: {clf_name}')
    print(f'Average Accuracy: {avg_accuracy:.4f}')
    print(f'Average Precision: {avg_precision:.4f}')
    print(f'Average Recall: {avg_recall:.4f}')
    print('-----------------------')
# Out:
# Classifier: Logistic Regression
# Average Accuracy: 0.9500
# Average Precision: 0.9497
# Average Recall: 0.9491
# -----------------------
# Classifier: Decision Tree
# Average Accuracy: 0.9583
# Average Precision: 0.9189
# Average Recall: 0.9491
# -----------------------
# Classifier: Random Forest
# Average Accuracy: 0.9500
# Average Precision: 0.9497
# Average Recall: 0.9491
# -----------------------
# Classifier: KNN
# Average Accuracy: 0.9667
# Average Precision: 0.9680
# Average Recall: 0.9657
# -----------------------
# Classifier: XGB
# Average Accuracy: 0.9333
# Average Precision: 0.9350
# Average Recall: 0.9324
# -----------------------

# %%
from sklearn.metrics import accuracy_score

# Créer le classifieur KNN
knn = KNeighborsClassifier(n_neighbors=3)  

# Entraîner le classifieur
knn.fit(Xtrain, Ytrain)




# Prédiction sur les données de test
ypred = knn.predict(Xtest)

# Évaluation du modèle
#Compute Accuracy
evaluate_model(Ytest,ypred)

from sklearn.metrics import roc_curve, auc


# Calcul des probabilités prédites par le modèle
y_pred_prob = knn.predict_proba(Xtest)[:,1]

# Calcul de la courbe ROC
fpr, tpr, thresholds = roc_curve(Ytest, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Tracer la courbe ROC
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Courbe d'apprentissage
plt.figure()
plt.plot(thresholds, tpr, label='True Positive Rate')
plt.plot(thresholds, 1-fpr, label='1 - False Positive Rate')
plt.xlabel('Threshold')
plt.title('Learning Curve')
plt.legend()
plt.show()
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.92      1.00      0.96        11
#            2       1.00      0.92      0.96        12
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
#
#
# ---------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 26
#      23 y_pred_prob = knn.predict_proba(Xtest)[:,1]
#      25 # Calcul de la courbe ROC
# ---> 26 fpr, tpr, thresholds = roc_curve(Ytest, y_pred_prob)
#      27 roc_auc = auc(fpr, tpr)
#      29 # Tracer la courbe ROC
#
# ...

# %%
#Method to evaluate the performance of the model
def evaluate_model(Ytest,y_pred):
    print("Classification Report")
    print(classification_report(Ytest, y_pred))
    
    print("\n---------------------------------------------\n")
    # Compute confusion matrix
    cm = confusion_matrix(Ytest, y_pred)

    # Create a heatmap of the confusion matrix using Seaborn
    sns.heatmap(cm, annot=True, cmap='Blues',fmt='.0f')

    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')

    plt.show()

# %%
import os
PATH = os.getcwd()

# %%
PATH
# Out:
# 'C:\\Users\\dell\\Documents\\ML_projects\\mymodel'

# %%
# le module qui permet l'enregistrement de notre modèle
import joblib

joblib.dump(knn, PATH+'/iris.pkl')
# Out:
# ['C:\\Users\\dell\\Documents\\ML_projects\\mymodel/iris.pkl']
